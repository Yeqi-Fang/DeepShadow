# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"D:\GitHub\DeepShadow\logs_recognition\size\2024-02-14_20-16-58\mse-28.594.csv", index_col=0)
df
# Out:
#            Pred  Real
# 0     63.812150  64.0
# 1     70.301210  73.0
# 2     71.842290  69.0
# 3     68.561646  69.0
# 4     70.497940  72.0
# ...         ...   ...
# 5399  65.176570  66.0
# 5400  64.257560  65.0
# 5401  67.301315  67.0
# 5402  66.909870  71.0
# 5403  65.062690  65.0
#
# [5404 rows x 2 columns]

# %%
plt.figure(figsize=(7, 7))
plt.scatter(df.Pred, df.Real, s=1000, alpha=0.002)
x = np.arange(60, 78)
y = x
plt.plot(x, y, 'o-', color='#FFC75F')
plt.xlim(60, 77)
plt.ylim(60, 77)
# Out:
# (60.0, 77.0)
