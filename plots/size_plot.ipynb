# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid", font_scale=1.2, font="Times New Roman")
# plt.rcParams['font.size'] = 12
# plt.rcParams["font.family"] = "Times New Roman"
# sns.set()

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Times New Roman'
matplotlib.rcParams['mathtext.it'] = 'Times New Roman:italic'
matplotlib.rcParams['mathtext.bf'] = 'Times New Roman:bold'

# %%
df = pd.read_csv(r"D:\GitHub\DeepShadow\logs_recognition\size\2024-02-14_20-52-22\mse-13.204.csv", index_col=0)
df
# Out:
#            Pred  Real
# 0     64.718850  64.0
# 1     73.463880  73.0
# 2     69.480480  69.0
# 3     68.509476  69.0
# 4     72.595550  72.0
# ...         ...   ...
# 5399  65.517710  66.0
# 5400  64.019040  65.0
# 5401  67.534020  67.0
# 5402  69.379150  71.0
# 5403  64.638850  65.0
#
# [5404 rows x 2 columns]

# %%
plt.figure(figsize=(7, 7))
plt.scatter(df.Pred, df.Real, s=1000, alpha=0.002)
x = np.arange(60, 78)
y = x
plt.plot(x, y, 'o-', color='#FFC75F')
plt.xlim(60, 77)
plt.ylim(60, 77)
# Out:
# (60.0, 77.0)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
palette = sns.color_palette('mako_r', n_colors=13)
sns.violinplot(x=df.Real.astype(int), y=df.Pred, inner=None, ax=ax, palette=palette)
newax = fig.add_axes(ax.get_position(), frameon=False)
x = np.arange(64, 75)
y = x
# with sns.set_theme(style="darkgrid"):
newax.plot(x, y, '-', color='#dcbe87', markersize=6, lw=2)
newax.plot(x, y, 'o', color='#FFC75F', markersize=6, lw=2)
newax.grid(False)
# ax.set_xlim(60, 77)
ax.set_ylim(df.Pred.min() - 0.6, df.Pred.max() + 0.6)
newax.set_ylim(df.Pred.min() - 0.6, df.Pred.max() + 0.6)
ax.set_xlabel('Real size of black hole (px)')
ax.set_ylabel('Predicted distribution of the size (px)')
# plt.savefig('images/violin.png', dpi=600)
# plt.savefig('images/violin.pdf', dpi=600)
# Out:
# c:\Users\FYQ\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\FYQ\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\FYQ\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0, 0.5, 'Predicted distribution of the size (px)')

# %%
from pathlib import Path
root_path = Path("../logs_recognition/size")

# %%
csv_paths = [ 'csv/mse-9.855.csv', 'csv/mse-15.637.csv', 'csv/mse-42.169.csv']
angular_sizes = [1e-3, 1.2e-4, 9e-5]
mae = [0.346, 0.613, 1.291]

# %%
# for index, csv_path in enumerate(csv_paths):
#     df = pd.read_csv(csv_path, index_col=0)
#     fig, ax = plt.subplots(figsize=(7, 7))
#     palette = sns.color_palette('mako_r', n_colors=13)
#     sns.violinplot(x=df.Real.astype(int), y=df.Pred, inner=None, ax=ax, palette=palette)
#     newax = fig.add_axes(ax.get_position(), frameon=False)
#     x = np.arange(64, 75)
#     y = x
#     # with sns.set_theme(style="darkgrid"):
#     newax.plot(x, y, '-', color='#dcbe87', markersize=6, lw=2)
#     newax.plot(x, y, 'o', color='#FFC75F', markersize=6, lw=2)
#     newax.grid(False)
#     # ax.set_xlim(60, 77)
#     ax.set_ylim(60, 77)
#     newax.set_ylim(60, 77)
#     newax.set_xticklabels([])
#     newax.set_yticklabels([])
#     if index !=0:
#         ax.set_yticklabels([])
#         ax.set_ylabel('')
#     else:
#         ax.set_ylabel('Predicted distribution of the size (px)')
#     ax.set_xlabel('Real size of black hole (px)')
    
#     # plt.tight_layout()
#     plt.savefig(f'images/violin_{angular_size[index]}_{mae[index]}.png', dpi=600)
#     plt.savefig(f'images/violin_{angular_size[index]}_{mae[index]}.pdf')

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
for index, csv_path in enumerate(csv_paths):
    ax = axes[index]
    # ax.axis('square')
    df = pd.read_csv(csv_path, index_col=0)
    palette = sns.color_palette('mako_r', n_colors=13)
    sns.violinplot(x=df.Real.astype(int), y=df.Pred, inner=None, ax=ax, palette=palette)
    # fig.tight_layout()
    # ax.set_xlim(60, 77)
    ax.set_ylim(60, 77)

    if index !=0:
        # ax.set_yticklabels([])
        ax.set_ylabel('')
    else:
        ax.set_ylabel('Predicted distribution of the size (px)')
    ax.set_xlabel(rf'Real size, MAE$={mae[index]:.1f}, \theta={angular_sizes[index]*64/3.87e-3:.2f}\theta_c$')
    # ax.set_xticks(np.arange(64, 74, 2))

fig.tight_layout()
for index, csv_path in enumerate(csv_paths):
    ax = axes[index]
    df = pd.read_csv(csv_path, index_col=0)
    newax = fig.add_axes(ax.get_position(), frameon=False)
    x = np.arange(64, 75)
    y = x
    # with sns.set_theme(style="darkgrid"):
    newax.plot(x, y, '-', color='#FFC75F', markersize=6, lw=2, alpha=0.8)
    # newax.plot(x, y, '-', color='#dcbe87', markersize=6, lw=2, alpha=0.5)
    newax.plot(x, y, 'o', color='#FFC75F', markersize=6, lw=2)
    newax.set_ylim(60, 77)
    newax.grid(False)
    newax.set_xticklabels([])
    newax.set_yticklabels([])
    
plt.savefig(f'images/violin3.png', dpi=600)
plt.savefig(f'images/violin3.pdf')
# Out:
# c:\Users\FYQ\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\FYQ\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\FYQ\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
