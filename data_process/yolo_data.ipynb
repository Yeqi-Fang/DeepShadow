# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_excel('results.xlsx')
df.drop(['date', 'Model_name'], axis=1, inplace=True)
df_cut = df[['angular_pixel_size_input_image', 'precision', 'recall', 'mAP_0.5', 'mAP_0.5:0.95']]
df_cut = df_cut.sort_values(by=['angular_pixel_size_input_image'], ascending=False)
df_cut
# Out:
#    angular_pixel_size_input_image  precision   recall  mAP_0.5  mAP_0.5:0.95
# 1                        0.000120    0.63633  0.66113  0.87324      0.645180
# 0                        0.000100    0.79535  0.72408  0.88177      0.643280
# 2                        0.000080    0.90539  0.66841  0.84523      0.528800
# 3                        0.000060    0.92369  0.42450  0.65467      0.403560
# 4                        0.000055    0.55387  0.64861  0.60519      0.310690
# 5                        0.000045    0.62542  0.51090  0.56864      0.320930
# 6                        0.000040    0.58108  0.57350  0.52674      0.298970
# 7                        0.000035    0.62491  0.54475  0.53846      0.243600
# 8                        0.000030    0.54014  0.47626  0.45547      0.179360
# 9                        0.000025    0.42770  0.42950  0.31348      0.098152

# %%
plt.plot(df_cut['angular_pixel_size_input_image'], df_cut['mAP_0.5'], 'o--')
