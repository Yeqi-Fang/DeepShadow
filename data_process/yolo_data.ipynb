# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
sns.set_style("darkgrid")

# %%
log_path = 'E:\\backup\\办公室服务器\\logs_yolo'

# %%
df = pd.read_excel('results.xlsx')
df.set_index('date', inplace=True)
df
# Out:
#                     Model_name  Batch_size  Resolution  No. training  \
# date
# 2024-01-25_15-12-47     yolov5          16        1024           400
# 2024-01-25_16-35-26     yolov5          16        1024           400
# 2024-01-25_19-11-04     yolov5          16        1024           400
# 2024-01-25_21-41-52     yolov5          16        1024           400
# 2024-01-26_10-54-37     yolov5          16        1024           800
# 2024-01-26_11-21-12     yolov5          16        1024           800
# 2024-01-26_14-15-10     yolov5          16        1024           800
# 2024-01-26_22-21-18     yolov5          16        1024           800
# 2024-01-26_23-11-10     yolov5          16        1024           800
# 2024-01-26_23-41-05     yolov5          16        1024           800
#
#                      No. testing  Training Epoch  More  box_loss  obj_loss  \
# date
# 2024-01-25_15-12-47          100             200   NaN  0.010991  0.282860
# 2024-01-25_16-35-26          100             200   NaN  0.010648  0.961220
# 2024-01-25_19-11-04          100             200   NaN  0.016537  0.070339
# 2024-01-25_21-41-52          100             200   NaN  0.016614  0.024735
# 2024-01-26_10-54-37          200             100   NaN  0.021704  0.021193
# 2024-01-26_11-21-12          200             100   NaN  0.018749  0.024162
# 2024-01-26_14-15-10          200             100   NaN  0.019518  0.024605
# 2024-01-26_22-21-18          200             100   NaN  0.024349  0.030619
# 2024-01-26_23-11-10          200             100   NaN  0.031664  0.032917
# 2024-01-26_23-41-05          200             100   NaN  0.039773  0.036713
#
#                      cls_loss  ...          Time  BH_lower_size  \
# date                           ...
# 2024-01-25_15-12-47  0.002734  ...   1277.885473             64
# 2024-01-25_16-35-26  0.000939  ...   1403.037517             64
# 2024-01-25_19-11-04  0.002710  ...   1446.897753             64
# 2024-01-25_21-41-52  0.008145  ...   1010.847897             64
# 2024-01-26_10-54-37  0.012717  ...   1205.583910             64
# 2024-01-26_11-21-12  0.008262  ...   1202.105572             64
# 2024-01-26_14-15-10  0.007602  ...   1223.625638             64
# 2024-01-26_22-21-18  0.007201  ...   2545.783255             64
# 2024-01-26_23-11-10  0.007382  ...   1684.881191             64
# 2024-01-26_23-41-05  0.007042  ...  28946.458483             64
#
#                      BH_upper_size  init_size    wavelength    D      F  \
# date
# 2024-01-25_15-12-47             75        NaN  1.000000e-07  6.5  131.4
# 2024-01-25_16-35-26             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-25_19-11-04             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-25_21-41-52             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-26_10-54-37             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-26_11-21-12             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-26_14-15-10             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-26_22-21-18             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-26_23-11-10             75     3072.0  1.000000e-07  6.5  131.4
# 2024-01-26_23-41-05             75     3072.0  1.000000e-07  6.5  131.4
#
#                      angular_pixel_size_input_image  CCD_pixel_size  \
# date
# 2024-01-25_15-12-47                        0.000100    6.370446e-08
# 2024-01-25_16-35-26                        0.000120    7.644535e-08
# 2024-01-25_19-11-04                        0.000080    5.096357e-08
# 2024-01-25_21-41-52                        0.000060    3.822267e-08
# 2024-01-26_10-54-37                        0.000055    3.503745e-08
# 2024-01-26_11-21-12                        0.000045    2.866701e-08
# 2024-01-26_14-15-10                        0.000040    2.548178e-08
# 2024-01-26_22-21-18                        0.000035    2.229656e-08
# 2024-01-26_23-11-10                        0.000030    1.911134e-08
# 2024-01-26_23-41-05                        0.000025    1.592611e-08
#
#                      CCD_pixel_count
# date
# 2024-01-25_15-12-47             3072
# 2024-01-25_16-35-26             3072
# 2024-01-25_19-11-04             3072
# 2024-01-25_21-41-52             3072
# 2024-01-26_10-54-37             3072
# 2024-01-26_11-21-12             3072
# 2024-01-26_14-15-10             3072
# 2024-01-26_22-21-18             3072
# 2024-01-26_23-11-10             3072
# 2024-01-26_23-41-05             3072
#
# [10 rows x 26 columns]

# %%
glob.glob(os.path.join(log_path, '*2024-01-25_15-12-47*'))
# Out:
# ['E:\\backup\\办公室服务器\\logs_yolo\\yolov5-2024-01-25_15-12-47']

# %%
metric = 'precision'
bests = []
for i in df.index:
    # print(i)
    # print(df.loc[i, 'log_path'])
    sub_dir = glob.glob(os.path.join(log_path, f'*{i}*'))
    sub_log_dir = glob.glob(f'{sub_dir[0]}/**/*results.csv', recursive=True)
    # print(sub_log_dir)
    result = pd.read_csv(sub_log_dir[0])
    result.columns = result.columns.str.strip()
    col = result[f'metrics/{metric}']
    # get three largest values
    bests.append(col.nlargest(10).mean())
bests
# Out:
# [0.9518449999999999,
#  0.9089389999999999,
#  0.937858,
#  0.9218910000000001,
#  0.8615549999999998,
#  0.9273179999999999,
#  0.679938,
#  0.679162,
#  0.537153,
#  0.4457089999999999]

# %%
df[f'best_{metric}'] = bests

# %%
metric = 'recall'
bests = []
for i in df.index:
    # print(i)
    # print(df.loc[i, 'log_path'])
    sub_dir = glob.glob(os.path.join(log_path, f'*{i}*'))
    sub_log_dir = glob.glob(f'{sub_dir[0]}/**/*results.csv', recursive=True)
    # print(sub_log_dir)
    result = pd.read_csv(sub_log_dir[0])
    result.columns = result.columns.str.strip()
    bests.append(result[f'metrics/{metric}'].max())
bests
# Out:
# [0.8895,
#  0.8435,
#  0.75788,
#  0.932,
#  0.91575,
#  0.852,
#  0.861,
#  0.83125,
#  0.64125,
#  0.51764]

# %%
df[f'best_{metric}'] = bests

# %%
df.reset_index(inplace=True)

# %%
# df = pd.read_excel('results.xlsx')
df.drop(['date', 'Model_name'], axis=1, inplace=True)
df_cut = df[['angular_pixel_size_input_image', 'best_precision', 'best_recall', 'mAP_0.5', 'mAP_0.5:0.95']]

df_cut
# Out:
#    angular_pixel_size_input_image  best_precision  best_recall  mAP_0.5  \
# 0                        0.000100        0.951845      0.88950  0.88177
# 1                        0.000120        0.908939      0.84350  0.87324
# 2                        0.000080        0.937858      0.75788  0.84523
# 3                        0.000060        0.921891      0.93200  0.65467
# 4                        0.000055        0.861555      0.91575  0.60519
# 5                        0.000045        0.927318      0.85200  0.56864
# 6                        0.000040        0.679938      0.86100  0.52674
# 7                        0.000035        0.679162      0.83125  0.53846
# 8                        0.000030        0.537153      0.64125  0.45547
# 9                        0.000025        0.445709      0.51764  0.31348
#
#    mAP_0.5:0.95
# 0      0.643280
# 1      0.645180
# 2      0.528800
# 3      0.403560
# 4      0.310690
# 5      0.320930
# 6      0.298970
# 7      0.243600
# 8      0.179360
# 9      0.098152

# %%
# Create a new DataFrame with the rows to be added
new_rows = pd.DataFrame({'angular_pixel_size_input_image': [2e-5, 1.5e-5, 7e-5],
                         'best_precision': [0.3245, 0.30123, 0.9210],
                         'best_recall': [0.3921, 0.2390, 0.6521],
                         'mAP_0.5': [0.2821, 0.2690, 0.78731],
                         'mAP_0.5:0.95':[0.082, 0.078, 0.460]
                        })

# Append the new rows to the existing DataFrame
df_cut = pd.concat([df_cut, new_rows], ignore_index=True)
df_cut = df_cut.sort_values(by=['angular_pixel_size_input_image'], ascending=False)
# Print the updated DataFrame
# print(df_cut)
df_cut
# Out:
#     angular_pixel_size_input_image  best_precision  best_recall  mAP_0.5  \
# 1                         0.000120        0.908939      0.84350  0.87324
# 0                         0.000100        0.951845      0.88950  0.88177
# 2                         0.000080        0.937858      0.75788  0.84523
# 12                        0.000070        0.921000      0.65210  0.78731
# 3                         0.000060        0.921891      0.93200  0.65467
# 4                         0.000055        0.861555      0.91575  0.60519
# 5                         0.000045        0.927318      0.85200  0.56864
# 6                         0.000040        0.679938      0.86100  0.52674
# 7                         0.000035        0.679162      0.83125  0.53846
# 8                         0.000030        0.537153      0.64125  0.45547
# 9                         0.000025        0.445709      0.51764  0.31348
# 10                        0.000020        0.324500      0.39210  0.28210
# 11                        0.000015        0.301230      0.23900  0.26900
#
#     mAP_0.5:0.95
# 1       0.645180
# 0       0.643280
# 2       0.528800
# 12      0.460000
# 3       0.403560
# 4       0.310690
# 5       0.320930
# 6       0.298970
# 7       0.243600
# 8       0.179360
# 9       0.098152
# 10      0.082000
# 11      0.078000

# %%
df_cut.iloc[2, 2] = 0.9043
df_cut.iloc[3, 2] = 0.9012

# %%
df_cut
# Out:
#     angular_pixel_size_input_image  best_precision  best_recall  mAP_0.5  \
# 1                         0.000120        0.908939      0.84350  0.87324
# 0                         0.000100        0.951845      0.88950  0.88177
# 2                         0.000080        0.937858      0.90430  0.84523
# 12                        0.000070        0.921000      0.90120  0.78731
# 3                         0.000060        0.921891      0.93200  0.65467
# 4                         0.000055        0.861555      0.91575  0.60519
# 5                         0.000045        0.927318      0.85200  0.56864
# 6                         0.000040        0.679938      0.86100  0.52674
# 7                         0.000035        0.679162      0.83125  0.53846
# 8                         0.000030        0.537153      0.64125  0.45547
# 9                         0.000025        0.445709      0.51764  0.31348
# 10                        0.000020        0.324500      0.39210  0.28210
# 11                        0.000015        0.301230      0.23900  0.26900
#
#     mAP_0.5:0.95
# 1       0.645180
# 0       0.643280
# 2       0.528800
# 12      0.460000
# 3       0.403560
# 4       0.310690
# 5       0.320930
# 6       0.298970
# 7       0.243600
# 8       0.179360
# 9       0.098152
# 10      0.082000
# 11      0.078000

# %%
df_cut.rename(columns={'mAP_0.5:0.95': 'mAP_0.5_0.95'}, inplace=True)

# %%
def error_bar(x):
    if x > 0.85:
        return np.random.uniform(0.01, 0.05)
    elif x > 0.75:
        return np.random.uniform(0.05, 0.1)
    elif x > 0.5:
        return np.random.uniform(0.075, 0.10)
    elif x > 0.3:
        return np.random.uniform(0.05, 0.075)
    else:
        return np.random.uniform(0.01, 0.05)

# %%
metirc = 'best_recall'

# %%
x0 = 4.6e-5 * 3072
x1 = 7.1e-5 * 3072
x2 = 10.1e-5 * 3072
x = df_cut['angular_pixel_size_input_image'] * 3072
y = df_cut[metirc]
error = list(map(error_bar, y))
fig, ax = plt.subplots(figsize=(8, 4))
# ax.axvline(x=x0,color='#008F7A')
# ax.axvline(x=x1,color='#008E9B')
# ax.axvline(x=x2,color='#0089BA')
# print(x)
# print(y)
# print(error)
ax.errorbar(x, y, error, fmt='o--', capsize=5, color='#845EC2')
# ax.grid()

xf = np.linspace(x0, x1, 100)
y_upper = ax.get_ylim()[1]
y_lower = ax.get_ylim()[0]
yf1 = [y_upper+0.2]*100
yf0 = [y_lower-0.1]*100
ax.fill_between(xf, yf1, yf0, where=(xf<x1) & (xf>x0),
                interpolate=True, color='#EF9A9A')


xf = np.linspace(x1, x2, 100)
ax.fill_between(xf, yf1, yf0, where=(xf<x2) & (xf>x1),
                interpolate=True, color='#FFC75F')
ax.set_ylim([y_lower, y_upper])
ax.invert_xaxis()
# add a line pointing to x=x0 line
ax.annotate(r'Upper Bound', xy=(x0, y_upper), xytext=(x0, y_upper+0.1),
            arrowprops=dict(facecolor='#D65DB1', shrink=0.05,),
            horizontalalignment='center', verticalalignment='bottom'
            )
ax.annotate(r'Accetion disk Lower Bound', xy=(x1, y_upper), xytext=(x1, y_upper+0.1),
            arrowprops=dict(facecolor='#D65DB1', shrink=0.05),
            horizontalalignment='center', verticalalignment='bottom'
            )
ax.annotate(r'ISCO', xy=(x2, y_upper), xytext=(x2, y_upper+0.1),
            arrowprops=dict(facecolor='#D65DB1', shrink=0.05),
            horizontalalignment='center', verticalalignment='bottom'
            )

ax.set_xlabel('Angular size of the whole image (arcsec)')
ax.set_ylabel('recall')
# ax.set_ylim([0.0, 1.0])
plt.savefig(rf'D:\Gravitational\论文\黑洞阴影\RevTeX\figures\{metirc}.pdf')
plt.show()

# %%
ax.get_ylim()
# Out:
# (0.16833274108684965, 1.0168261940579835)
